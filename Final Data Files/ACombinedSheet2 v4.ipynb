# %%
import requests,pandas as pd
import numpy as np
import json
from pandas import json_normalize

# Display full number versus scientific notation
pd.set_option('display.float_format', lambda x: '%.3f' % x)

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %%
# Create a Pandas Excel writer using XlsxWriter as the engine.
writer = pd.ExcelWriter('JMACData02.xlsx', engine='xlsxwriter')

# %%
url = 'https://vpic.nhtsa.dot.gov/api/vehicles/GetAllMakes?format=json';
r = requests.get(url);
print("This provides a list of all the Makes available in vPIC Dataset.")
print()
dict = json.loads(r.text)
Makes = pd.json_normalize(dict['Results']) 
Makes.to_excel(writer, sheet_name='Sheet1-Makes')
Makes
# Out:
# This provides a list of all the Makes available in vPIC Dataset.
#        Make_ID             Make_Name
# 0          440          ASTON MARTIN
# 1          441                 TESLA
# 2          442                JAGUAR
# 3          443              MASERATI
# 4          444            LAND ROVER
# ...        ...                   ...
# 10157    11636         ROCKET MARINE
# 10158    11637                   LVT
# 10159    11638  J & J TRAILER REPAIR
# 10160    11639              XOTO INC
# 10161    11640                 ULURU
#
# [10162 rows x 2 columns]

# %%
url = 'https://vpic.nhtsa.dot.gov/api/vehicles/GetMakesForVehicleType/car?format=json';
r = requests.get(url);
print("This returns all the Makes in the vPIC dataset for a specified vehicle type whose name contains CAR.")
print()
dict = json.loads(r.text)
Car_Type_Vehicle = pd.json_normalize(dict['Results']) 
Car_Type_Vehicle.to_excel(writer, sheet_name='Sheet2A-Car_Type_Vehicle')
Car_Type_Vehicle
# Out:
# This returns all the Makes in the vPIC dataset for a specified vehicle type whose name contains CAR.
#      MakeId                             MakeName  VehicleTypeId VehicleTypeName
# 0       440                         ASTON MARTIN              2   Passenger Car
# 1       441                                TESLA              2   Passenger Car
# 2       442                               JAGUAR              2   Passenger Car
# 3       443                             MASERATI              2   Passenger Car
# 4       445                          ROLLS ROYCE              2   Passenger Car
# 5       448                               TOYOTA              2   Passenger Car
# 6       449                        MERCEDES-BENZ              2   Passenger Car
# 7       452                                  BMW              2   Passenger Car
# 8       454                              BUGATTI              2   Passenger Car
# ...

# %%
url = 'https://vpic.nhtsa.dot.gov/api/vehicles/GetMakesForVehicleType/truck?format=json';
r = requests.get(url);
print("This returns all the Makes in the vPIC dataset for a specified vehicle type whose name contains TRUCK.")
print()
dict = json.loads(r.text)
Truck_Type_Vehicle = pd.json_normalize(dict['Results']) 
Truck_Type_Vehicle.to_excel(writer, sheet_name='Sheet2B-Truck_Type_Vehicle')
Truck_Type_Vehicle
# Out:
# This returns all the Makes in the vPIC dataset for a specified vehicle type whose name contains TRUCK.
#      MakeId                               MakeName  VehicleTypeId VehicleTypeName
# 0       448                                 TOYOTA              3          Truck
# 1       449                          MERCEDES-BENZ              3          Truck
# 2       450                           FREIGHTLINER              3          Truck
# 3       460                                   FORD              3          Truck
# 4       464                                LINCOLN              3          Truck
# 5       465                                MERCURY              3          Truck
# 6       467                              CHEVROLET              3          Truck
# 7       469                               CADILLAC              3          Truck
# 8       472                                    GMC              3          Truck
# ...

# %%
url = 'https://vpic.nhtsa.dot.gov/api/vehicles/GetMakesForVehicleType/Moto?format=json';
r = requests.get(url);
print("This returns all the Makes in the vPIC dataset for a specified vehicle type whose name contains MOTO.")
print()
dict = json.loads(r.text)
Moto_Vehicle = pd.json_normalize(dict['Results']) 
Moto_Vehicle.to_excel(writer, sheet_name='Sheet2C-Moto_Vehicle')
Moto_Vehicle
# Out:
# This returns all the Makes in the vPIC dataset for a specified vehicle type whose name contains MOTO.
#       MakeId                          MakeName  VehicleTypeId VehicleTypeName
# 0        446                               EBR              1      Motorcycle
# 1        447                           JIALING              1      Motorcycle
# 2        451               FULMER FABRICATIONS              1      Motorcycle
# 3        452                               BMW              1      Motorcycle
# 4        453  MOTORCYCLE MACHINE SHOP SERVICES              1      Motorcycle
# ...      ...                               ...            ...             ...
# 1425   11581                           HUANGHE              1      Motorcycle
# 1426   11583       CHONGQING HUANGHE / MASSIMO              1      Motorcycle
# 1427   11624                             ANCHI              1      Motorcycle
# 1428   11625                          FLY WING              1      Motorcycle
# ...

# %%
url = 'https://vpic.nhtsa.dot.gov/api/vehicles/GetMakesForVehicleType/Trailer?format=json';
r = requests.get(url);
print("This returns all the Makes in the vPIC dataset for a specified vehicle type whose name contains TRAILER.")
print()
dict = json.loads(r.text)
Trailer_Vehicle = pd.json_normalize(dict['Results']) 
Trailer_Vehicle.to_excel(writer, sheet_name='Sheet2D-Trailer_Vehicle')
Trailer_Vehicle
# Out:
# This returns all the Makes in the vPIC dataset for a specified vehicle type whose name contains TRAILER.
#       MakeId              MakeName  VehicleTypeId VehicleTypeName
# 0        455      HOMBILT TRAILERS              6         Trailer
# 1        461              LATITUDE              6         Trailer
# 2        479   QUEST MANUFACTURING              6         Trailer
# 3        485                 VOLVO              6         Trailer
# 4        495             PETERBILT              6         Trailer
# ...      ...                   ...            ...             ...
# 7905   11635                    JQ              6         Trailer
# 7906   11636         ROCKET MARINE              6         Trailer
# 7907   11637                   LVT              6         Trailer
# 7908   11638  J & J TRAILER REPAIR              6         Trailer
# 7909   11640                 ULURU              6         Trailer
#
# [7910 rows x 4 columns]

# %%
url = 'https://vpic.nhtsa.dot.gov/api/vehicles/GetMakesForVehicleType/Vehicle?format=json';
r = requests.get(url);
print("This returns all the Makes in the vPIC dataset for a specified vehicle type whose name contains VEHICLE.")
print()
dict = json.loads(r.text)
VEH_Vehicle = pd.json_normalize(dict['Results']) 
VEH_Vehicle.to_excel(writer, sheet_name='Sheet2E-VEH_Vehicle')
VEH_Vehicle
# Out:
# This returns all the Makes in the vPIC dataset for a specified vehicle type whose name contains VEHICLE.
#      MakeId                              MakeName  VehicleTypeId                       VehicleTypeName
# 0       440                          ASTON MARTIN              7  Multipurpose Passenger Vehicle (MPV)
# 1       441                                 TESLA              7  Multipurpose Passenger Vehicle (MPV)
# 2       442                                JAGUAR              7  Multipurpose Passenger Vehicle (MPV)
# 3       443                              MASERATI              7  Multipurpose Passenger Vehicle (MPV)
# 4       444                            LAND ROVER              7  Multipurpose Passenger Vehicle (MPV)
# ..      ...                                   ...            ...                                   ...
# 518   11551                               CENNTRO              9               Low Speed Vehicle (LSV)
# ...

# %%
VTypes = pd.DataFrame()
VTypes = pd.concat([Car_Type_Vehicle, Truck_Type_Vehicle, Moto_Vehicle, Trailer_Vehicle, VEH_Vehicle], axis=0)
VTypes = VTypes.sort_values('MakeId')
VTypes.index = np.arange(1,len(VTypes)+1)
VTypes.to_excel(writer, sheet_name='Sheet2Z-VehicleTypes')
VTypes
# Out:
#        MakeId              MakeName  VehicleTypeId                       VehicleTypeName
# 1         440          ASTON MARTIN              2                         Passenger Car
# 2         440          ASTON MARTIN              7  Multipurpose Passenger Vehicle (MPV)
# 3         441                 TESLA              2                         Passenger Car
# 4         441                 TESLA              7  Multipurpose Passenger Vehicle (MPV)
# 5         442                JAGUAR              2                         Passenger Car
# ...       ...                   ...            ...                                   ...
# 10192   11636         ROCKET MARINE              6                               Trailer
# 10193   11637                   LVT              6                               Trailer
# 10194   11638  J & J TRAILER REPAIR              6                               Trailer
# ...

# %%
url = 'https://vpic.nhtsa.dot.gov/api/vehicles/GetEquipmentPlantCodes?year=2015&equipmentType=1&reportType=all&format=json';
r = requests.get(url);
print("This provides a list of all the Equipment Plants and Codes in vPIC Dataset.")
print()
dict = json.loads(r.text)
Eqip_Plant = pd.json_normalize(dict['Results']) 
Eqip_Plant = Eqip_Plant.replace(to_replace = "UNITED STATES (USA)", value="UNITED STATES")
Eqip_Plant = Eqip_Plant.replace(to_replace = "United States (USA)", value="UNITED STATES")
Eqip_Plant = Eqip_Plant.replace(to_replace = "UNITED KINGDOM (UK)", value="UNITED KINGDOM")
Eqip_Plant = Eqip_Plant.replace(to_replace = "MYANMAR (BURMA)", value="MYANMAR")
Eqip_Plant['Country'] = Eqip_Plant['Country'].str.upper()
Eqip_Plant['StateProvince'] = Eqip_Plant['StateProvince'].str.upper()
Eqip_Plant = Eqip_Plant.set_index('DOTCode')
Eqip_Plant.to_excel(writer, sheet_name='Sheet4A-Eqip_Plant')
Eqip_Plant
# Out:
# This provides a list of all the Equipment Plants and Codes in vPIC Dataset.
#                                                    Address              City        Country                                               Name OldDotCode PostalCode     StateProvince  Status
# DOTCode
# 00T                               2950 International Blvd.       Clarksville  UNITED STATES           Hankook Tire Manufacturing Tennessee, LP                 37040                TN  Active
# 020                                 1850 BARTON FERRY ROAD        WEST POINT  UNITED STATES                    YOKOHAMA TIRE MANUFACTURER, LLC                 39773       MISSISSIPPI  Closed
# 030      No. 52 Street 536, Bau Tran Hamlet, Nhuan Duc ...       Ho Chi Minh        VIETNAM           SHIH FA RUBBER INDUSTRIES (VN) CO., LTD.                  None              None  Active
# ...

# %%
EPStatus = pd.DataFrame()
EPStatus = Eqip_Plant.groupby('Status').size()
Eqip_Plant.to_excel(writer, sheet_name='Sheet4B-EP-Status')
EPStatus
# Out:
# Status
# Active    1053
# Closed      42
# dtype: int64

# %%
EPLocation = pd.DataFrame()
EPLocation = Eqip_Plant.groupby('Country').size()

EPLocation.to_excel(writer, sheet_name='Sheet4C-EPLocation')
EPLocation
# Out:
# Country
# AFRICA                         1
# ALGERIA                        2
# ARGENTINA                      4
# ARMENIA                        1
# AUSTRAILIA                     6
# BELARUS                        2
# BELGIUM                        2
# BRAZIL                        21
# CAMBODIA                       2
# CANADA                        15
# CHILE                          1
# CHINA                        473
# COLOMBIA                       5
# COSTA RICA                     1
# CZECH REPUBLIC                 6
# ECUADOR                        1
# EGYPT                          3
# ENGLAND                        4
# ETHIOPIA                       1
# FINLAND                        1
# FRANCE                        24
# GERMANY                       28
# GRAND DUCHY OF LUXEMBOURG      2
# HUNGARY                        5
# INDIA                         66
# INDONESIA                     20
# IRAN                           1
# ISRAEL                         2
# ...

# %%
EPAct = pd.DataFrame()
EPActive = pd.DataFrame()

EPAct = Eqip_Plant[Eqip_Plant['Status'] != 'Closed']
EPActive = EPAct.groupby('Country').size()
EPLocation.to_excel(writer, sheet_name='Sheet4D-EP-Active')
EPActive
# Out:
# Country
# AFRICA                         1
# ALGERIA                        2
# ARGENTINA                      4
# ARMENIA                        1
# AUSTRAILIA                     4
# BELARUS                        2
# BELGIUM                        1
# BRAZIL                        20
# CAMBODIA                       2
# CANADA                        14
# CHILE                          1
# CHINA                        461
# COLOMBIA                       5
# COSTA RICA                     1
# CZECH REPUBLIC                 6
# ECUADOR                        1
# EGYPT                          3
# ENGLAND                        4
# ETHIOPIA                       1
# FINLAND                        1
# FRANCE                        23
# GERMANY                       27
# GRAND DUCHY OF LUXEMBOURG      2
# HUNGARY                        5
# INDIA                         65
# INDONESIA                     20
# IRAN                           1
# ISRAEL                         2
# ...

# %%
url = 'https://vpic.nhtsa.dot.gov/api/vehicles/GetVehicleVariableList?format=json';
r = requests.get(url);
print("This provides a list of all the Vehicle related variables that are in vPIC dataset.")
print("Information on the name, description and the type of the variable is provided.")
print()
dict = json.loads(r.text)
Variables = pd.json_normalize(dict['Results']) 
Variables.to_excel(writer, sheet_name='Sheet5-Variables')
Variables
# Out:
# This provides a list of all the Vehicle related variables that are in vPIC dataset.
# Information on the name, description and the type of the variable is provided.
#     DataType                                        Description                                          GroupName   ID                                               Name
# 0     string  <p>This field stores any other battery informa...                               Mechanical / Battery    1                                 Other Battery Info
# 1     lookup  <p>Battery type field stores the battery chemi...                               Mechanical / Battery    2                                       Battery Type
# 2     lookup  <p>Bed type is the type of bed (the open back)...                                   Exterior / Truck    3                                           Bed Type
# ...

# %%
url = 'https://vpic.nhtsa.dot.gov/api/vehicles/GetAllManufacturers?format=json&page=1';
r = requests.get(url);
print("This provides a list of all the Manufactures that are in vPIC dataset page 1.")

print()
dict = json.loads(r.text)
MF1 = pd.json_normalize(dict['Results']) 
MF1 = MF1.replace(to_replace = "UNITED STATES (USA)", value="UNITED STATES")
MF1 = MF1.replace(to_replace = "United States (USA)", value="UNITED STATES")
MF1 = MF1.replace(to_replace = "UNITED KINGDOM (UK)", value="UNITED KINGDOM")
MF1 = MF1.replace(to_replace = "MYANMAR (BURMA)", value="MYANMAR")
MF1['Country'] = MF1['Country'].str.upper()

MF1
# Out:
# This provides a list of all the Manufactures that are in vPIC dataset page 1.
#            Country                    Mfr_CommonName  Mfr_ID                                           Mfr_Name                                       VehicleTypes
# 0    UNITED STATES                             Tesla     955                                        TESLA, INC.  [{'IsPrimary': True, 'Name': 'Passenger Car'},...
# 1   UNITED KINGDOM                      Aston Martin     956                       ASTON MARTIN LAGONDA LIMITED  [{'IsPrimary': False, 'Name': 'Passenger Car'}...
# 2    UNITED STATES                               BMW     957                          BMW OF NORTH AMERICA, LLC                                                 []
# 3    UNITED STATES                              None     958                          JAGUAR LAND ROVER NA, LLC  [{'IsPrimary': True, 'Name': 'Passenger Car'},...
# ...

# %%
url = 'https://vpic.nhtsa.dot.gov/api/vehicles/GetAllManufacturers?format=json&page=2';
r = requests.get(url);
print("This provides a list of all the Manufactures that are in vPIC dataset page 2.")

print()
dict = json.loads(r.text)
MF2 = pd.json_normalize(dict['Results']) 
MF2 = MF2.replace(to_replace = "UNITED STATES (USA)", value="UNITED STATES")
MF2 = MF2.replace(to_replace = "United States (USA)", value="UNITED STATES")
MF2 = MF2.replace(to_replace = "UNITED KINGDOM (UK)", value="UNITED KINGDOM")
MF2 = MF2.replace(to_replace = "MYANMAR (BURMA)", value="MYANMAR")
MF2['Country'] = MF2['Country'].str.upper()

MF2
# Out:
# This provides a list of all the Manufactures that are in vPIC dataset page 2.
#           Country               Mfr_CommonName  Mfr_ID                                           Mfr_Name                                       VehicleTypes
# 0           CHINA                         None    1080          GEELY GROUP ZHEJIANG MOTORCYCLE CO., LTD.       [{'IsPrimary': False, 'Name': 'Motorcycle'}]
# 1           JAPAN        Mitsubishi Fuso Truck    1081            MITSUBISHI FUSO TRUCK & BUS CORPORATION                                                 []
# 2          MEXICO                        Mazda    1083   MAZDA MOTOR MANUFACTURING DE MEXICO S.A. DE C.V.                                                 []
# 3   UNITED STATES           FOREST RIVER, INC.    1084                                 FOREST RIVER, INC.  [{'IsPrimary': False, 'Name': 'Truck '}, {'IsP...
# ...

# %%
url = 'https://vpic.nhtsa.dot.gov/api/vehicles/GetAllManufacturers?format=json&page=3';
r = requests.get(url);
print("This provides a list of all the Manufactures that are in vPIC dataset page 3.")

print()
dict = json.loads(r.text)
MF3 = pd.json_normalize(dict['Results']) 
MF3 = MF3.replace(to_replace = "UNITED STATES (USA)", value="UNITED STATES")
MF3 = MF3.replace(to_replace = "United States (USA)", value="UNITED STATES")
MF3 = MF3.replace(to_replace = "UNITED KINGDOM (UK)", value="UNITED KINGDOM")
MF3 = MF3.replace(to_replace = "MYANMAR (BURMA)", value="MYANMAR")
MF3['Country'] = MF3['Country'].str.upper()

MF3
# Out:
# This provides a list of all the Manufactures that are in vPIC dataset page 3.
#           Country                              Mfr_CommonName  Mfr_ID                                           Mfr_Name                                       VehicleTypes
# 0   UNITED STATES                         58th Street Customs    1179                                58TH STREET CUSTOMS                                                 []
# 1          CANADA                            9013-7233 Quebec    1180                              9013-7233 QUEBEC INC.          [{'IsPrimary': False, 'Name': 'Trailer'}]
# 2   UNITED STATES                                A&E Trailers    1181                                     A & E TRAILERS                                                 []
# 3   UNITED STATES                            A&M Fabrications    1182                             A & M FABRICATIONS LLC          [{'IsPrimary': False, 'Name': 'Trailer'}]
# ...

# %%
url = 'https://vpic.nhtsa.dot.gov/api/vehicles/GetAllManufacturers?format=json&page=4';
r = requests.get(url);
print("This provides a list of all the Manufactures that are in vPIC dataset page 4.")

print()
dict = json.loads(r.text)
MF4 = pd.json_normalize(dict['Results']) 
MF4 = MF4.replace(to_replace = "UNITED STATES (USA)", value="UNITED STATES")
MF4 = MF4.replace(to_replace = "United States (USA)", value="UNITED STATES")
MF4 = MF4.replace(to_replace = "UNITED KINGDOM (UK)", value="UNITED KINGDOM")
MF4 = MF4.replace(to_replace = "MYANMAR (BURMA)", value="MYANMAR")
MF4['Country'] = MF4['Country'].str.upper()

MF4
# Out:
# This provides a list of all the Manufactures that are in vPIC dataset page 4.
#           Country          Mfr_CommonName  Mfr_ID                                           Mfr_Name                                       VehicleTypes
# 0   UNITED STATES                    None    1287                            CRAFTON EQUIPMENT, INC.          [{'IsPrimary': False, 'Name': 'Trailer'}]
# 1   UNITED STATES                    None    1288                             AMERICAN PRODUCTS, LLC                                                 []
# 2   UNITED STATES                    None    1289                              Coyne Oil Corporation                                                 []
# 3   UNITED STATES               CRONKHITE    1290                         CRONKHITE INDUSTRIES, INC.           [{'IsPrimary': True, 'Name': 'Trailer'}]
# ...

# %%
url = 'https://vpic.nhtsa.dot.gov/api/vehicles/GetAllManufacturers?format=json&page=5';
r = requests.get(url);
print("This provides a list of all the Manufactures that are in vPIC dataset page 5.")

print()
dict = json.loads(r.text)
MF5 = pd.json_normalize(dict['Results']) 
MF5 = MF5.replace(to_replace = "UNITED STATES (USA)", value="UNITED STATES")
MF5 = MF5.replace(to_replace = "United States (USA)", value="UNITED STATES")
MF5 = MF5.replace(to_replace = "UNITED KINGDOM (UK)", value="UNITED KINGDOM")
MF5 = MF5.replace(to_replace = "MYANMAR (BURMA)", value="MYANMAR")
MF5['Country'] = MF5['Country'].str.upper()

MF5
# Out:
# This provides a list of all the Manufactures that are in vPIC dataset page 5.
#           Country Mfr_CommonName  Mfr_ID                                           Mfr_Name                                       VehicleTypes
# 0   UNITED STATES           None    1389                      WORCESTER WHITE AUTOCAR, INC.                                                 []
# 1   UNITED STATES           None    1390                                    WORKBENCH, INC.          [{'IsPrimary': False, 'Name': 'Trailer'}]
# 2   UNITED STATES           None    1391                              U-SCREEN U.S.A., INC.          [{'IsPrimary': False, 'Name': 'Trailer'}]
# 3   UNITED STATES           None    1392                         L AND T MANUFACTURING, LLC           [{'IsPrimary': True, 'Name': 'Trailer'}]
# 4   UNITED STATES           None    1393                       DAUNTLESS MOTORS CORPORATION           [{'IsPrimary': True, 'Name': 'Trailer'}]
# ...

# %%
url = 'https://vpic.nhtsa.dot.gov/api/vehicles/GetAllManufacturers?format=json&page=6';
r = requests.get(url);
print("This provides a list of all the Manufactures that are in vPIC dataset page 6.")

print()
dict = json.loads(r.text)
MF6 = pd.json_normalize(dict['Results']) 
MF6 = MF6.replace(to_replace = "UNITED STATES (USA)", value="UNITED STATES")
MF6 = MF6.replace(to_replace = "United States (USA)", value="UNITED STATES")
MF6 = MF6.replace(to_replace = "UNITED KINGDOM (UK)", value="UNITED KINGDOM")
MF6 = MF6.replace(to_replace = "MYANMAR (BURMA)", value="MYANMAR")
MF6['Country'] = MF6['Country'].str.upper()

MF6
# Out:
# This provides a list of all the Manufactures that are in vPIC dataset page 6.
#           Country      Mfr_CommonName  Mfr_ID                                           Mfr_Name                                       VehicleTypes
# 0   UNITED STATES                None    1486                            PALMER INDUSTRIES, INC.        [{'IsPrimary': True, 'Name': 'Motorcycle'}]
# 1   UNITED STATES                None    1487                                 ZTPOWERSTATION LLC                                                 []
# 2   UNITED STATES                None    1488                                              FEMCO                                                 []
# 3   UNITED STATES                None    1489                      PACE AMERICAN OF GEORGIA INC.                                                 []
# 4   UNITED STATES                None    1490                        PACE AMERICAN OF TEXAS INC.                                                 []
# ...

# %%
url = 'https://vpic.nhtsa.dot.gov/api/vehicles/GetAllManufacturers?format=json&page=7';
r = requests.get(url);
print("This provides a list of all the Manufactures that are in vPIC dataset page 7.")

print()
dict = json.loads(r.text)
MF7 = pd.json_normalize(dict['Results']) 
MF7 = MF7.replace(to_replace = "UNITED STATES (USA)", value="UNITED STATES")
MF7 = MF7.replace(to_replace = "United States (USA)", value="UNITED STATES")
MF7 = MF7.replace(to_replace = "UNITED KINGDOM (UK)", value="UNITED KINGDOM")
MF7 = MF7.replace(to_replace = "MYANMAR (BURMA)", value="MYANMAR")
MF7['Country'] = MF7['Country'].str.upper()

MF7
# Out:
# This provides a list of all the Manufactures that are in vPIC dataset page 7.
#            Country Mfr_CommonName  Mfr_ID                                           Mfr_Name                                       VehicleTypes
# 0    UNITED STATES           None    1574                       EBERT PRECISION PRODUCTS LLC                                                 []
# 1            CHINA           None    1575                      DEZHOU FULU VEHICLE CO., LTD.        [{'IsPrimary': True, 'Name': 'Motorcycle'}]
# 2    UNITED STATES           None    1576                         TRAILERS INC. OF HILL CITY                                                 []
# 3    UNITED STATES           None    1577                           AMERIFAB INDUSTRIES INC.                                                 []
# 4    UNITED STATES           None    1578                                        DATTCO INC.  [{'IsPrimary': False, 'Name': 'Passenger Car'}...
# ...

# %%
url = 'https://vpic.nhtsa.dot.gov/api/vehicles/GetAllManufacturers?format=json&page=8';
r = requests.get(url);
print("This provides a list of all the Manufactures that are in vPIC dataset page 8.")

print()
dict = json.loads(r.text)
MF8 = pd.json_normalize(dict['Results']) 
MF8 = MF8.replace(to_replace = "UNITED STATES (USA)", value="UNITED STATES")
MF8 = MF8.replace(to_replace = "United States (USA)", value="UNITED STATES")
MF8 = MF8.replace(to_replace = "UNITED KINGDOM (UK)", value="UNITED KINGDOM")
MF8 = MF8.replace(to_replace = "MYANMAR (BURMA)", value="MYANMAR")
MF8['Country'] = MF8['Country'].str.upper()

MF8
# Out:
# This provides a list of all the Manufactures that are in vPIC dataset page 8.
#           Country Mfr_CommonName  Mfr_ID                                           Mfr_Name                                       VehicleTypes
# 0           CHINA           None    1666              HANGZHOU YUANFAN AUTO PARTS CO., LTD.                                                 []
# 1   UNITED STATES           None    1667                               BACK 40 SUPPLY INC.            [{'IsPrimary': True, 'Name': 'Trailer'}]
# 2   UNITED STATES           None    1668                              COOL CITY CUSTOMS LLC                                                 []
# 3   UNITED STATES           None    1669                                   AMAZE-N-TOW, LLC           [{'IsPrimary': True, 'Name': 'Trailer'}]
# 4   UNITED STATES           None    1670                               ROCK BOTTOM CHOPPERS        [{'IsPrimary': True, 'Name': 'Motorcycle'}]
# ...

# %%
url = 'https://vpic.nhtsa.dot.gov/api/vehicles/GetAllManufacturers?format=json&page=9';
r = requests.get(url);
print("This provides a list of all the Manufactures that are in vPIC dataset page 9.")

print()
dict = json.loads(r.text)
MF9 = pd.json_normalize(dict['Results']) 
MF9 = MF9.replace(to_replace = "UNITED STATES (USA)", value="UNITED STATES")
MF9 = MF9.replace(to_replace = "United States (USA)", value="UNITED STATES")
MF9 = MF9.replace(to_replace = "UNITED KINGDOM (UK)", value="UNITED KINGDOM")
MF9 = MF9.replace(to_replace = "MYANMAR (BURMA)", value="MYANMAR")
MF9['Country'] = MF9['Country'].str.upper()

MF9
# Out:
# This provides a list of all the Manufactures that are in vPIC dataset page 9.
#           Country         Mfr_CommonName  Mfr_ID                                           Mfr_Name                                       VehicleTypes
# 0                                   None    1777                                        CYCLEHAULER                                                 []
# 1   UNITED STATES                   None    1778                 CYGNUS MANUFACTURING COMPANY (CMC)                                                 []
# 2   UNITED STATES                   None    1779                            CYPRESS VAN CONVERSIONS  [{'IsPrimary': False, 'Name': 'Multipurpose Pa...
# 3   UNITED STATES                   None    1780                                   D & D INDUSTRIES                                                 []
# 4   UNITED STATES                   None    1781                                          D & D MFG                                                 []
# ...

# %%
url = 'https://vpic.nhtsa.dot.gov/api/vehicles/GetAllManufacturers?format=json&page=10';
r = requests.get(url);
print("This provides a list of all the Manufactures that are in vPIC dataset page 10.")

print()
dict = json.loads(r.text)
MF10 = pd.json_normalize(dict['Results']) 
MF10 = MF10.replace(to_replace = "UNITED STATES (USA)", value="UNITED STATES")
MF10 = MF10.replace(to_replace = "United States (USA)", value="UNITED STATES")
MF10 = MF10.replace(to_replace = "UNITED KINGDOM (UK)", value="UNITED KINGDOM")
MF10 = MF10.replace(to_replace = "MYANMAR (BURMA)", value="MYANMAR")
MF10['Country'] = MF10['Country'].str.upper()

MF10
# Out:
# This provides a list of all the Manufactures that are in vPIC dataset page 10.
#           Country    Mfr_CommonName  Mfr_ID                                           Mfr_Name                                       VehicleTypes
# 0   UNITED STATES              None    1894                                      BARON USA INC                                                 []
# 1   UNITED STATES              None    1895                        BARRETO MANUFACTURING, INC.           [{'IsPrimary': True, 'Name': 'Trailer'}]
# 2   UNITED STATES              None    1896                               BARRETT EQUIP., INC.                                                 []
# 3   UNITED STATES  Barrett Trailers    1897                               BARRETT TRAILERS LLC          [{'IsPrimary': False, 'Name': 'Trailer'}]
# 4   UNITED STATES              None    1898                          BART TRUCK EQUIPMENT LLC.  [{'IsPrimary': True, 'Name': 'Truck '}, {'IsPr...
# ...

# %%
MF0 = pd.DataFrame()
MF0 = pd.concat([MF1, MF2, MF3, MF4, MF5, MF6, MF7, MF8, MF9, MF10], axis=0)
MF0 = MF0.set_index('Mfr_ID')
MF0.to_excel(writer, sheet_name='Sheet3-ManufacturerList')
MF0
# Out:
#                Country Mfr_CommonName                             Mfr_Name                                       VehicleTypes
# Mfr_ID
# 955      UNITED STATES          Tesla                          TESLA, INC.  [{'IsPrimary': True, 'Name': 'Passenger Car'},...
# 956     UNITED KINGDOM   Aston Martin         ASTON MARTIN LAGONDA LIMITED  [{'IsPrimary': False, 'Name': 'Passenger Car'}...
# 957      UNITED STATES            BMW            BMW OF NORTH AMERICA, LLC                                                 []
# 958      UNITED STATES           None            JAGUAR LAND ROVER NA, LLC  [{'IsPrimary': True, 'Name': 'Passenger Car'},...
# 959      UNITED STATES       Maserati         MASERATI NORTH AMERICA, INC.  [{'IsPrimary': False, 'Name': 'Passenger Car'}...
# ...                ...            ...                                  ...                                                ...
# ...

# %%
# Close the Pandas Excel writer and output the Excel file.
writer.save()
